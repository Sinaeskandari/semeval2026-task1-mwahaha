# %% [markdown]
# # Synthetic Instruction Data Generation
#
# **Pipeline stage:** Synthetic-data construction (Paper §3 — *Data*).
#
# Starting from the length-balanced sample produced by
# [`sample_shortjokes.ipynb`](../sample_shortjokes.ipynb), this notebook uses a
# Gemini teacher model to turn each raw joke into a structured
# **`(instruction, reasoning, improved_joke)`** triple:
#
# - **`instruction`** — a natural user request that *would* elicit the joke
#   (topic/style-specific, phrased in varied ways).
# - **`reasoning`** — a one–two sentence analysis of the humor mechanism
#   (pun, irony, subversion of expectation, …).
# - **`improved_joke`** — a lightly polished version with corrected timing.
#
# The result (`synthetic_data.jsonl`) is the instruction-tuning corpus consumed by
# the LoRA experiments in `src/fine_tuning/Lora/`. Generation is **resumable**
# (completed IDs are skipped) and defensively skips API responses blocked for
# safety, recitation, or truncation.
#
# > Set `API_KEY` to your own Gemini key (do **not** commit it) and point the
# > input/output paths at your data directory before running.

# %%
import os
import pandas as pd
import numpy as np
from tqdm.notebook import tqdm
import json
import time


import google.generativeai as genai
import typing_extensions as typing
from google.api_core import retry

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
def create_prompt(joke) :
  prompt = f"""
Here is a raw joke:
"{joke}"

Based on this joke, generate a JSON object with the following three fields:

1. "instruction": Write a natural, human-like prompt asking for this specific joke.
   - Do not just say "Tell me a joke."
   - Include the specific topic, style, or format of the joke (e.g., "Tell me a dad joke about chemistry," "I need a witty one-liner about marriage," "Give me a pun about fruit").
   - Vary the phrasing (e.g., "Make me laugh with...", "Do you know any jokes about...", "Crack a joke regarding...").

2. "reasoning": A concise analysis (1-2 sentences) of why the joke works.
   - Identify the humor mechanism (e.g., wordplay, pun, double entendre, subversion of expectation, irony).
   - Explain the connection (e.g., "The humor relies on the double meaning of the word 'date' as both a fruit and a social meeting.").

3. "improved_joke": The joke itself, but polished.
   - Fix any typos, capitalization, or punctuation errors from the raw input.
   - Ensure the timing is correct (use newlines or punctuation to separate setup and punchline).

Output strictly valid JSON. Do not include markdown formatting (like ```json). Just the raw JSON string."""

  return prompt

# %%
class JokeSchema(typing.TypedDict):
    instruction: str
    reasoning: str
    improved_joke: str

generation_config = {
    "temperature": 0.7,
    "top_p": 0.9,
    "response_mime_type": "application/json",  # FIXED: responseMimeType -> response_mime_type
    "max_output_tokens": 2048,     # FIXED: maxOutputTokens -> max_output_tokens

    # FIXED: responseSchema -> response_schema
    # You can pass the class directly (JokeSchema) or the raw dict, but the key must be snake_case
    "response_schema": JokeSchema
}

my_retry_policy = retry.Retry(
    initial=1.0,       # Wait just 1 second (was 10.0)
    multiplier=2.0,    # Double the wait (1s -> 2s -> 4s...)
    maximum=15.0,      # Cap the wait at 10 seconds (was 60.0)
    timeout=40.0       # Give up after 30 seconds total (was 300.0)
)

# --- CONFIGURATION ---
API_KEY = ""
genai.configure(api_key=API_KEY)

model = genai.GenerativeModel('gemini-3-flash-preview')

# %%
def append_entry(
    output_path: str,
    original_id: int,
    response : str
):
    new_entry = json.loads(response)
    new_entry["ID"] = original_id

    # Open with 'a' (append) to add to the end of the file
    with open(output_path, "a", encoding="utf-8") as f:
        f.write(json.dumps(new_entry) + "\n")

# %%
input_path = "/content/drive/MyDrive/LLM project/DATA/sampled_shortjokes.csv"
output_path = "/content/drive/MyDrive/LLM project/DATA/synthetic_data.jsonl"

# %%
def generate_data(input_path: str, output_path: str):
    # Load input
    if os.path.exists(input_path):
        df = pd.read_csv(input_path)
    else:
        print("Could not locate the input file")
        return

    # Check for progress
    existing_ids = set() # Using a set is much faster for checking "if x in ids"
    if os.path.exists(output_path):
        try:
            existing_df = pd.read_json(output_path, lines=True)
            existing_ids = set(existing_df["ID"].tolist())
            print(f"Resuming: Found {len(existing_ids)} existing entries.")
        except Exception:
            print("Found existing file but could not read it. Starting fresh or check format.")

    for index, row in tqdm(df.iterrows(), total=len(df)):
        joke_id = int(row["ID"])

        if joke_id in existing_ids:
            continue

        try:
            response = model.generate_content(
                create_prompt(row["Joke"]),
                generation_config=generation_config,
                request_options={'retry': my_retry_policy}
            )

            # SAFETY CHECKS
            candidate = response.candidates[0]
            finish_reason = candidate.finish_reason.name

            # 1. Check for Safety Blocks specifically
            if finish_reason == "SAFETY":
                print(f"🚫 ID {joke_id}: Blocked by Safety Filters.")
                continue

            # 2. Check for other non-success reasons (like Recitation or Max Tokens)
            if finish_reason != "STOP":
                print(f"⚠️ ID {joke_id}: Skipped. Finish Reason: {finish_reason}")
                continue

            # 3. Check for empty text (just in case)
            if not response.text:
                print(f"⚠️ ID {joke_id}: Response was empty.")
                continue

            append_entry(
                output_path=output_path,
                original_id=joke_id,
                response=response.text
            )

        except Exception as e:
            print(f"\nError at ID {joke_id}: {e}")
            # If it's a serious API error, you might want to wait longer
            time.sleep(1)
            continue

    print("\nGeneration complete!")

# %%
generate_data(input_path, output_path)
# Out:
#   0%|          | 0/3500 [00:00<?, ?it/s]
# ⚠️ ID 2181: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 3548: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 6350: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 10636: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 12105: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 12457: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 19951: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 20144: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 23319: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 27262: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 27612: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 27794: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 28090: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 28756: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 28759: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 29004: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 31254: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 32078: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 35668: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 36113: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 42958: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 43615: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 45758: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 48107: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 48115: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 50306: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 51720: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 54147: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 55771: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 57127: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 57420: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 58481: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 60785: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 64814: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 67129: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 67606: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 68447: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 68878: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 79049: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 79331: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 80394: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 80513: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 81068: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 81186: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 85469: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 86620: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 87340: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 87455: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 89920: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 90018: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 91281: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 91932: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 95769: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 96574: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 98067: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 99461: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 101848: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 102744: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 104700: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 104796: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 107039: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 109919: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 110245: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 114018: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 114104: Skipped. Finish Reason: PROHIBITED_CONTENT
# ⚠️ ID 115999: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 119351: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 119666: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 120380: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 121142: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 124302: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 132262: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 133715: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 135703: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 137148: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 144175: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 146891: Skipped. Finish Reason: RECITATION
# ⚠️ ID 151693: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 155823: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 157462: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 158222: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 158730: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 161512: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 162434: Skipped. Finish Reason: RECITATION
# ⚠️ ID 168262: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 169462: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 170155: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 171207: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 171853: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 172379: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 173091: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 173263: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 174404: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 174830: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 176337: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 179127: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 181016: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 181821: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 182834: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 188975: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 189790: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 194580: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 195154: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 197829: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 200881: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 203238: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 210375: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 211363: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 211487: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 213946: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 215415: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 215863: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 216793: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 221872: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 222667: Skipped. Finish Reason: MAX_TOKENS
# ⚠️ ID 224190: Skipped. Finish Reason: MAX_TOKENS
#
# Generation complete!
